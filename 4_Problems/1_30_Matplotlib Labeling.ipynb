# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_30_Matplotlib Labeling.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install -U datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🟩 Bar Chart with Labels (1.30.1)

# %%
values = df['job_title_short'].unique()
counts = df['job_title_short'].value_counts()
counts.plot(kind='bar')
plt.ylabel("NUmber of jobs per job title")
plt.xlabel("Number of jobs titles")
plt.xticks(rotation=45,ha='right')
plt.title("Jobs available in each category")
# Out:
# Text(0.5, 1.0, 'Jobs available in each category')

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Horizontal Bar Chart with Labels (1.30.2)

# %%
values = df['job_title_short'].unique()
counts = df['job_title_short'].value_counts().sort_values()
counts.plot(kind='barh')
plt.ylabel("NUmber of jobs per job title")
plt.xlabel("Number of jobs titles")
plt.xticks(rotation=45,ha='right')
plt.title("Jobs available in each category")
# Out:
# Text(0.5, 1.0, 'Jobs available in each category')

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Line Chart with Labels (1.30.3)

# %%
values = df['job_title_short'].unique()
counts = df['job_title_short'].value_counts().sort_values()
counts.plot(kind='line')
plt.ylabel("NUmber of jobs per job title")
plt.xlabel("Number of jobs titles")
plt.xticks(ticks=range(len(counts)),labels = counts.index,rotation=45,ha='right')
plt.title("Jobs available in each category")
plt.tight_layout()
plt.figure(figsize=(12,6))

# %% [markdown]
# ---
