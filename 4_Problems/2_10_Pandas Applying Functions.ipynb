# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_10_Pandas Applying Functions.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install -U datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# ## 🟩 Convert Date to String (2.10.1)

# %%
date = str(df['job_posted_date'].iloc[10])
type(date)
# Out:
# str

# %%
df['job_posted_date'] = df['job_posted_date'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Days Since Posted (2.10.2)

# %%
from datetime import datetime
today = pd.to_datetime(datetime.today().date())
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['days_since_posted'] = (today - df['job_posted_date']).dt.days
display(df[['job_posted_date', 'days_since_posted']].head())
# Out:
#       job_posted_date  days_since_posted
# 0 2023-06-16 13:44:15                739
# 1 2023-01-14 13:18:07                892
# 2 2023-10-10 13:14:55                623
# 3 2023-07-04 13:01:41                721
# 4 2023-08-07 14:29:36                687

# %%
from datetime import datetime
import pandas as pd

# Method to calculate days between today and a given date
def days_since_posted(posted_date):
    today = pd.to_datetime(datetime.today().date())
    posted_date = pd.to_datetime(posted_date)
    return (today - posted_date).days

# Apply this method to the column
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['days_since_posted'] = df['job_posted_date'].apply(days_since_posted)

# Optional: Display sample
display(df[['job_posted_date', 'days_since_posted']].head())
# Out:
#       job_posted_date  days_since_posted
# 0 2023-06-16 13:44:15                739
# 1 2023-01-14 13:18:07                892
# 2 2023-10-10 13:14:55                623
# 3 2023-07-04 13:01:41                721
# 4 2023-08-07 14:29:36                687

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Salary Category (2.10.3)

# %%
df_altered = df.dropna(subset = ['salary_year_avg']).copy()
display(df_altered.head())
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %% [markdown]
# ---

# %%
def sal_category(salary):
  if salary > 10000:
    return "Low"
  elif salary > 20000:
    return "Medium"
  else:
    return "High"

# %%
 df_altered['salary_category'] =  df_altered['salary_year_avg'].apply(sal_category)

# %%
df_altered['salary_category']
# Out:
# 28        Low
# 77        Low
# 92        Low
# 100       Low
# 109       Low
#          ...
# 785624    Low
# 785641    Low
# 785648    Low
# 785682    Low
# 785692    Low
# Name: salary_category, Length: 22003, dtype: object
