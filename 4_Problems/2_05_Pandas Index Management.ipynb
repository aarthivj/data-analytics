# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_05_Pandas Index Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install -U datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Set Index and Display Rows (2.5.1)

# %%
df.set_index('job_title_short')
# Out:
#                                                               job_title  \
# job_title_short
# Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# Data Analyst                                               Data Analyst
# Data Engineer         Data Engineer/Scientist/Analyst, Mid or Senior...
# Data Engineer         LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# Data Engineer                                    Data Engineer- Sr Jobs
# ...                                                                 ...
# Software Engineer                                       DevOps Engineer
# Data Analyst                                           CRM Data Analyst
# Business Analyst                         Commercial Analyst - Start Now
# Data Engineer         Principal Associate, Data Engineer (Remote-Eli...
# Software Engineer                                    AWS System Analyst
#
#                                              job_location  \
# job_title_short
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Reset Index and Drop Existing (2.5.2)

# %%
df.reset_index()
# Out:
#          index       job_title_short  \
# 0            0  Senior Data Engineer
# 1            1          Data Analyst
# 2            2         Data Engineer
# 3            3         Data Engineer
# 4            4         Data Engineer
# ...        ...                   ...
# 785736  785736     Software Engineer
# 785737  785737          Data Analyst
# 785738  785738      Business Analyst
# 785739  785739         Data Engineer
# 785740  785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Sort Index (2.5.3)

# %%
df=df.set_index(df['job_posted_date'].dt.month)

# %%
df.sort_index()
# Out:
#                    job_title_short  \
# job_posted_date
# 1                   Data Scientist
# 1                Software Engineer
# 1                    Data Engineer
# 1                    Data Engineer
# 1                   Data Scientist
# ...                            ...
# 12                  Data Scientist
# 12                    Data Analyst
# 12                   Data Engineer
# 12                  Data Scientist
# 12                    Data Analyst
#
#                                                          job_title  \
# job_posted_date
# 1                                                     Data Modeler
# 1                                      Principal Software Engineer
# 1                                          Es- Data Engineer Azure
# 1                                                    Data Engineer
# 1                                                   Data Scientist
# ...                                                            ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Pivot Table Reset & Set Index (2.5.4)

# %%
df['job_via'].str.contains('Linkedin',case=False,na=False).value_counts()
# Out:
# job_via
# False    586050
# True     199691
# Name: count, dtype: int64

# %%
job_types = df['job_schedule_type'].value_counts().head().index
job_types
# Out:
# Index(['Full-time', 'Contractor', 'Internship', 'Part-time',
#        'Full-time and Part-time'],
#       dtype='object', name='job_schedule_type')

# %%
filtered_data = df[df['job_schedule_type'].isin(job_types)]
filtered_data
# Out:
#                       job_title_short  \
# job_posted_date
# 6                Senior Data Engineer
# 1                        Data Analyst
# 10                      Data Engineer
# 7                       Data Engineer
# 8                       Data Engineer
# ...                               ...
# 4                    Business Analyst
# 1                        Data Analyst
# 1                    Business Analyst
# 1                        Data Analyst
# 11                      Data Engineer
#
#                                                          job_title  \
# job_posted_date
# 6                Senior Clinical Data Engineer / Principal Clin...
# 1                                                     Data Analyst
# 10               Data Engineer/Scientist/Analyst, Mid or Senior...
# 7                LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 8                                           Data Engineer- Sr Jobs
# ...

# %% [markdown]
# ---

# %%
job_types =df['job_title_short'].unique()

# %%
final_data = filtered_data.pivot_table(index='job_schedule_type',columns='job_title_short',values='company_name',aggfunc='count')
final_data
# Out:
# job_title_short          Business Analyst  Cloud Engineer  Data Analyst  \
# job_schedule_type
# Contractor                           1693             326         10009
# Full-time                           44106           11537        168971
# Full-time and Part-time               300              44          1587
# Internship                            455              30          3290
# Part-time                             416              84          3203
#
# job_title_short          Data Engineer  Data Scientist  \
# job_schedule_type
# Contractor                       11492            6150
# Full-time                       165221          153273
# Full-time and Part-time           1309            1828
# Internship                        1244            3225
# Part-time                         1216            2171
#
# job_title_short          Machine Learning Engineer  Senior Data Analyst  \
# job_schedule_type
# ...

# %%
final_data.plot(kind='line')
# Out:
# <Axes: xlabel='job_schedule_type'>
